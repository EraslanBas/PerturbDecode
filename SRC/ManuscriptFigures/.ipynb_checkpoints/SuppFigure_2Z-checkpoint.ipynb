# %%
source("Main.R")
source("Conf.R")
source("Utilities.R")
# Out:
# corrplot 0.92 loaded
#
#
# Attaching package: ‘pls’
#
#
# The following object is masked from ‘package:corrplot’:
#
#     corrplot
#
#
# The following object is masked from ‘package:stats’:
#
#     loadings
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     dcast, melt

# %%
nCellsGuide = read.csv("./../TextFiles/NoOfCellsPerGuide.csv")
nCellsGuide$cellRatio = nCellsGuide$nCellsScreen / nCellsGuide$nCellsPool
nCellsGuide$GuideType = "CONTROL"
nCellsGuide[nCellsGuide$type == "Gene", "GuideType"] = "KO Guide"

# %%
dim(nCellsGuide)
# Out:
# [1] 3719    9

# %%
3719 - 330
# Out:
# [1] 3389

# %%
1130 * 3
# Out:
# [1] 3390

# %%
options(repr.plot.width=6, repr.plot.height=5)

ggplot(nCellsGuide, aes(x=cellRatio, color=GuideType, fill=GuideType)) +
    #geom_histogram(aes(y=..density..), position="identity", alpha=0.2, binwidth = 0.02)+
    geom_density(alpha=0.1)+
    labs(x="(# of cells in the screen) / (# of cells in the initial pool) ", y = "Density")+
    theme_bw()+geom_vline(xintercept = 0.085, color="blue")
# Out:
# plot without title

# %%
options(repr.plot.width=7, repr.plot.height=4)
pdf("./../SupplementaryFigures/S_2Z.pdf", height=4, width=7)
ggplot(nCellsGuide, aes(cellRatio, colour = GuideType)) +
  stat_ecdf(geom = "step")+theme_minimal()+
labs(
     x="(# of guides in the screen) / (# of guides in the initial pool)", 
     y = "CDF")+theme(axis.text = element_text(size=15),
              axis.title =  element_text(size=16))+xlim(0, 1)+
geom_segment(aes(x = 0, y = 0.05, xend = 0.08587, yend = 0.05), color="blue")+
geom_segment(aes(x = 0.08587, y = 0, xend = 0.08587, yend = 0.05), color="blue")

dev.off()
#geom_hline(yintercept = 0.05, color="blue")
# Out:
# Warning message:
# “Removed 5 rows containing non-finite values (stat_ecdf).”
# png
#   2

# %%
k = nCellsGuide[nCellsGuide$GuideType == "CONTROL","cellRatio"]
d_fun <- ecdf (k)
d_fun(0.08587)
# Out:
# [1] 0.04863222

# %%
nCellsKOGuides = nCellsGuide[nCellsGuide$type == "Gene",]

# %%
for(i in 1:nrow(nCellsKOGuides)){
    nCellsKOGuides[i,"Pval"] = d_fun(nCellsKOGuides[i,"cellRatio"])
}

nCellsKOGuides$Gene = sapply(nCellsKOGuides$Guide, function(x){strsplit(x,"_")[[1]][1]})

# %%
write.csv(nCellsKOGuides, "GuideDepletion.csv", row.names=FALSE)

# %%
nCellsKOGuidesDepleted = nCellsKOGuides[nCellsKOGuides$Pval < 0.05,]

# %%
write.csv(nCellsKOGuidesDepleted, "GuideDepletion_ControlGuidesBackground.csv", row.names=FALSE)

# %%
hh <- table(nCellsKOGuidesDepleted$Gene)

# %%
hh = hh[order(hh)]
hh = hh[hh>1]

# %%
data.frame(GuideName=names(hh), NumberOfGuides=hh)
# Out:
#    GuideName     NumberOfGuides.Var1 NumberOfGuides.Freq
# 1  Aamp          Aamp                2
# 2  Aurka         Aurka               2
# 3  Btbd3         Btbd3               2
# 4  Cadps2        Cadps2              2
# 5  Chaf1b        Chaf1b              2
# 6  Dpf3          Dpf3                2
# 7  Eml2          Eml2                2
# 8  G2e3          G2e3                2
# 9  Gm19640       Gm19640             2
# 10 Gm3701        Gm3701              2
# 11 Gnb2          Gnb2                2
# 12 Grb2          Grb2                2
# 13 Hdac4         Hdac4               2
# 14 Herc1         Herc1               2
# 15 Ing1          Ing1                2
# 16 Keap1         Keap1               2
# 17 Klhl2         Klhl2               2
# 18 Kmt2a         Kmt2a               2
# 19 Myc           Myc                 2
# 20 Naca          Naca                2
# 21 Npm1          Npm1                2
# 22 Pex12         Pex12               2
# 23 Phip          Phip                2
# 24 Pias1         Pias1               2
# 25 Pias2         Pias2               2
# 26 Plk1          Plk1                2
# 27 Poc1a         Poc1a               2
# 28 Pou5f1        Pou5f1              2
# 29 Prc1          Prc1                2
# 30 Rack1         Rack1               2
# ⋮  ⋮             ⋮                   ⋮
# 36 Rnf222        Rnf222              2
# 37 Rnf7          Rnf7                2
# 38 Rwdd3         Rwdd3               2
# 39 Sart1         Sart1               2
# 40 Skp2          Skp2                2
# 41 Smad1         Smad1               2
# 42 Smad7         Smad7               2
# 43 Smu1          Smu1                2
# 44 Stap2         Stap2               2
# 45 Stat3         Stat3               2
# 46 Stc1          Stc1                2
# 47 Tle6          Tle6                2
# 48 Traip         Traip               2
# 49 Trim24        Trim24              2
# 50 Trim59        Trim59              2
# 51 Ube2i         Ube2i               2
# 52 Wdr31         Wdr31               2
# 53 Wdr49         Wdr49               2
# 54 Wdr5          Wdr5                2
# 55 Zbtb37        Zbtb37              2
# 56 8030462N17Rik 8030462N17Rik       3
# 57 Cdc20         Cdc20               3
# 58 Cdc27         Cdc27               3
# 59 Copa          Copa                3
# 60 Gnb4          Gnb4                3
# 61 Map3k7        Map3k7              3
# 62 Mdm2          Mdm2                3
# 63 Rnf20         Rnf20               3
# 64 Wdr43         Wdr43               3
# 65 Ybx1          Ybx1                3

# %%
head(nCellsKOGuidesDepleted)
# Out:
#   Guide     nCellsPool nCellsScreen type nCellsPoolPerc nCellsScreenPerc
# 1 Ret_3     192        0            Gene 1.022889e-04   0.000000e+00
# 3 Trim3_3   504        0            Gene 2.685084e-04   0.000000e+00
# 4 Lonrf2_3  772        0            Gene 4.112867e-04   0.000000e+00
# 5 Wdr3_2    500        1            Gene 2.663774e-04   2.929742e-06
# 6 Wdr27_1   176        1            Gene 9.376485e-05   2.929742e-06
# 7 Kbtbd12_2 552        1            Gene 2.940807e-04   2.929742e-06
#   nCellsScreenPoolPercDif cellRatio   GuideType Pval        Gene
# 1 -1.022889e-04           0.000000000 KO Guide  0.003039514 Ret
# 3 -2.685084e-04           0.000000000 KO Guide  0.003039514 Trim3
# 4 -4.112867e-04           0.000000000 KO Guide  0.003039514 Lonrf2
# 5 -2.634477e-04           0.002000000 KO Guide  0.003039514 Wdr3
# 6 -9.083511e-05           0.005681818 KO Guide  0.006079027 Wdr27
# 7 -2.911509e-04           0.001811594 KO Guide  0.003039514 Kbtbd12
