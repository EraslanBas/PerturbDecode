# %%
source("Main.R")
source("Conf.R")
source("Utilities.R")
source("DAVID_query.R")
library("factoextra")
library("maptree")
library(repr)
# Out:
# corrplot 0.84 loaded
#
#
# ********************************************************
#
# Note: As of version 1.0.0, cowplot does not change the
#
#   default ggplot2 theme anymore. To recover the previous
#
#   behavior, execute:
#   theme_set(theme_cowplot())
#
# ********************************************************
#
#
#
# Attaching package: ‘pls’
#
#
# The following object is masked from ‘package:corrplot’:
#
#     corrplot
#
#
# The following object is masked from ‘package:stats’:
#
#     loadings
#
#
# Loading required package: AnnotationDbi
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
# Loading required package: parallel
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:parallel’:
#
#     clusterApply, clusterApplyLB, clusterCall, clusterEvalQ,
#     clusterExport, clusterMap, parApply, parCapply, parLapply,
#     parLapplyLB, parRapply, parSapply, parSapplyLB
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, append, as.data.frame, basename, cbind, colnames,
#     dirname, do.call, duplicated, eval, evalq, Filter, Find, get, grep,
#     grepl, intersect, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, setdiff, sort, table, tapply,
#     union, unique, unsplit, which, which.max, which.min
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Loading required package: IRanges
#
# Loading required package: S4Vectors
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:base’:
#
#     expand.grid
#
#
#
#
#
# Attaching package: ‘data.table’
#
#
# The following object is masked from ‘package:IRanges’:
#
#     shift
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, second
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following objects are masked from ‘package:data.table’:
#
#     dcast, melt
#
#
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#
# Loading required package: cluster
#
# Loading required package: rpart

# %%
coefsAll <- as.data.frame(read.csv("/home/beraslan/jovian-work/analysisSingle/MixedEffectLMOutputs/ME_LMBetaCoefsALL.csv", row.names = 1), stringsAsFactors = FALSE)
#coefsAll <- as.data.frame(read.csv("/home/beraslan/jovian-work/analysisSingle/MixedEffectLMOutputs/ME_SignificantBetaCoefs.csv", row.names = 1), stringsAsFactors = FALSE)

# %%
dim(coefsAll)
# Out:
# [1] 1035 6685

# %%
koGuideNames <- sapply(rownames(coefsAll), function(x){strsplit(as.character(x),"_")[[1]][2]})

# %%
koGuideNames <- koGuideNames[!is.na(koGuideNames)]

# %%
length(koGuideNames)
# Out:
# [1] 1033

# %%
proComp <- data.frame(fread("/home/beraslan/jovian-work/analysisSingle/R/allComplexes.txt"), stringsAsFactors = F)
proComp <- proComp[proComp$Organism == "Mouse",]

# %%
guideModulesN <- data.frame(read.csv("/home/beraslan/jovian-work/analysisSingle/ME_GuideModules_leiden_6_Modules.csv"),  row.names = 1)
rownames(guideModulesN) <- guideModulesN$GuideName 
guideModulesN$GuideGroup <- factor(guideModulesN$GuideGroup)
guideModulesN$GuideColor <- NULL

# %%
guideModulesN$GuideName <- as.character(guideModulesN$GuideName)
guideModulesN$GuideGroup <- as.numeric(as.character(guideModulesN$GuideGroup))

# %%
head(guideModulesN)
# Out:
#        GuideName GuideGroup
# Aamp   Aamp      4
# Bop1   Bop1      4
# Cirh1a Cirh1a    4
# Dcaf13 Dcaf13    4
# Grb2   Grb2      4
# Myc    Myc       4

# %%
guideModulesSplit <- split(guideModulesN, guideModulesN$GuideGroup)

# %%
head(guideModulesSplit)
# Out:
# $`0`
#                 GuideName GuideGroup
# Ago2                 Ago2          0
# Ahr                   Ahr          0
# Anapc13           Anapc13          0
# Bach1               Bach1          0
# Baz1a               Baz1a          0
# Bid                   Bid          0
# Bptf                 Bptf          0
# Brca1               Brca1          0
# Brwd3               Brwd3          0
# Btbd1               Btbd1          0
# Cblc                 Cblc          0
# Ccnf                 Ccnf          0
# Cdc27               Cdc27          0
# Cntn4               Cntn4          0
# Copa                 Copa          0
# Copb2               Copb2          0
# Coro1a             Coro1a          0
# Cpne9               Cpne9          0
# Cul4b               Cul4b          0
# Ddb1                 Ddb1          0
# Dido1               Dido1          0
# E4f1                 E4f1          0
# Ecel1               Ecel1          0
# Fbxl14             Fbxl14          0
# Fbxl5               Fbxl5          0
# Fbxo11             Fbxo11          0
# Fbxo42             Fbxo42          0
# Fzr1                 Fzr1          0
# Gemin5             Gemin5          0
# Gm10697           Gm10697          0
# Gm9117             Gm9117          0
# Gtf2h2             Gtf2h2          0
# Gtf3c1             Gtf3c1          0
# Hdac4               Hdac4          0
# Hectd1             Hectd1          0
# Ift122             Ift122          0
# Ikbkg               Ikbkg          0
# Ing2                 Ing2          0
# Jun                   Jun          0
# Katnb1             Katnb1          0
# Kbtbd13           Kbtbd13          0
# Kdm2a               Kdm2a          0
# Klhl23             Klhl23          0
# Klhl3               Klhl3          0
# Kmt2b               Kmt2b          0
# LOC100861784 LOC100861784          0
# Lrr1                 Lrr1          0
# Lrrc41             Lrrc41          0
# Map3k7             Map3k7          0
# Mdm4                 Mdm4          0
# Mib1                 Mib1          0
# Mkrn1               Mkrn1          0
# Mnat1               Mnat1          0
# Naca                 Naca          0
# Nsmaf               Nsmaf          0
# Ogt                   Ogt          0
# Pa2g4               Pa2g4          0
# Pcif1               Pcif1          0
# Ppp1r11           Ppp1r11          0
# Prc1                 Prc1          0
# Ring1               Ring1          0
# Rnf128             Rnf128          0
# Rnf20               Rnf20          0
# Rnf225             Rnf225          0
# Rnf40               Rnf40          0
# Siah1a             Siah1a          0
# Siah2               Siah2          0
# Taf3                 Taf3          0
# Tdpoz2             Tdpoz2          0
# Tmem183a         Tmem183a          0
# Tnfsf11           Tnfsf11          0
# Tradd               Tradd          0
# Traf3ip2         Traf3ip2          0
# Trim35             Trim35          0
# Trim7               Trim7          0
# Tssc1               Tssc1          0
# Ttc3                 Ttc3          0
# Ube2n               Ube2n          0
# Ufl1                 Ufl1          0
# Unkl                 Unkl          0
# Upf1                 Upf1          0
# Vdr                   Vdr          0
# Wdhd1               Wdhd1          0
# Wdr48               Wdr48          0
# Wdr95               Wdr95          0
# Wwp1                 Wwp1          0
# Ybx1                 Ybx1          0
# Zbtb14             Zbtb14          0
# Zbtb49             Zbtb49          0
# Zbtb7a             Zbtb7a          0
# Zmiz1               Zmiz1          0
#
# $`1`
#          GuideName GuideGroup
# Akt1          Akt1          1
# Ankfy1      Ankfy1          1
# Apc            Apc          1
# Arpc1b      Arpc1b          1
# Birc2        Birc2          1
# Bmi1          Bmi1          1
# Bub3          Bub3          1
# Cacybp      Cacybp          1
# Cebpb        Cebpb          1
# Chd4          Chd4          1
# Crebbp      Crebbp          1
# Cul2          Cul2          1
# Dars          Dars          1
# Dcaf10      Dcaf10          1
# Dcaf4        Dcaf4          1
# Eif3f        Eif3f          1
# Eif3i        Eif3i          1
# Ep300        Ep300          1
# Fbxl13      Fbxl13          1
# Fbxo28      Fbxo28          1
# Fbxo3        Fbxo3          1
# Fbxw9        Fbxw9          1
# Gm13416    Gm13416          1
# Gnb1          Gnb1          1
# Gnb2          Gnb2          1
# Grb10        Grb10          1
# Klhl24      Klhl24          1
# Klhl7        Klhl7          1
# Kmt2c        Kmt2c          1
# Kmt2d        Kmt2d          1
# Mapk14      Mapk14          1
# Med8          Med8          1
# Mlst8        Mlst8          1
# Mtor          Mtor          1
# Nosip        Nosip          1
# Paf1          Paf1          1
# Pik3r4      Pik3r4          1
# Pparg        Pparg          1
# Ppp2r2a    Ppp2r2a          1
# Ppp2r2d    Ppp2r2d          1
# Preb          Preb          1
# Rbbp4        Rbbp4          1
# Rbbp5        Rbbp5          1
# Rheb          Rheb          1
# Rictor      Rictor          1
# Rnf10        Rnf10          1
# Rnf113a1  Rnf113a1          1
# Rnf135      Rnf135          1
# Rnf216      Rnf216          1
# Rptor        Rptor          1
# Scap          Scap          1
# Sec13        Sec13          1
# Sec31a      Sec31a          1
# Smad2        Smad2          1
# Syvn1        Syvn1          1
# Taf5l        Taf5l          1
# Traf2        Traf2          1
# Traf3        Traf3          1
# Traf7        Traf7          1
# Trim24      Trim24          1
# Trp53        Trp53          1
# Ube2e1      Ube2e1          1
# Ube2e3      Ube2e3          1
# Ube3c        Ube3c          1
# Ufm1          Ufm1          1
# Wdfy3        Wdfy3          1
# Wdr1          Wdr1          1
# Wdr82        Wdr82          1
# Whsc1        Whsc1          1
# Zbtb11      Zbtb11          1
#
# $`2`
#         GuideName GuideGroup
# Ahctf1     Ahctf1          2
# Anapc11   Anapc11          2
# Arih2       Arih2          2
# Arnt         Arnt          2
# Bcl6         Bcl6          2
# Brap         Brap          2
# Cbl           Cbl          2
# Cd28         Cd28          2
# Cstf1       Cstf1          2
# Cul1         Cul1          2
# Cul3         Cul3          2
# Cul5         Cul5          2
# Dda1         Dda1          2
# Fbxo33     Fbxo33          2
# Fbxw11     Fbxw11          2
# Fus           Fus          2
# Gm9840     Gm9840          2
# Hif1a       Hif1a          2
# Huwe1       Huwe1          2
# Ing3         Ing3          2
# Kcmf1       Kcmf1          2
# Kdm5c       Kdm5c          2
# Keap1       Keap1          2
# Maea         Maea          2
# Mycbp2     Mycbp2          2
# Nbeal1     Nbeal1          2
# Nedd8       Nedd8          2
# Nup43       Nup43          2
# Nup62       Nup62          2
# Phf8         Phf8          2
# Ptpn1       Ptpn1          2
# Rae1         Rae1          2
# Ranbp2     Ranbp2          2
# Rbbp6       Rbbp6          2
# Rbck1       Rbck1          2
# Rbx1         Rbx1          2
# Rc3h1       Rc3h1          2
# Rela         Rela          2
# Rlim         Rlim          2
# Rnf144a   Rnf144a          2
# Rnf31       Rnf31          2
# Rnf7         Rnf7          2
# Seh1l       Seh1l          2
# Skp1a       Skp1a          2
# Spop         Spop          2
# Ssr3         Ssr3          2
# Tbl1xr1   Tbl1xr1          2
# Tceb1       Tceb1          2
# Tceb2       Tceb2          2
# Tceb3       Tceb3          2
# Tdpoz5     Tdpoz5          2
# Thoc3       Thoc3          2
# Tlr4         Tlr4          2
# Traf6       Traf6          2
# Trim28     Trim28          2
# Trim33     Trim33          2
# Ube2d3     Ube2d3          2
# Ube2f       Ube2f          2
# Ube2h       Ube2h          2
# Ube2i       Ube2i          2
# Ubr4         Ubr4          2
# Ubr5         Ubr5          2
# Vhl           Vhl          2
# Wdr20       Wdr20          2
# Wdr26       Wdr26          2
# Wdr33       Wdr33          2
# Zbtb17     Zbtb17          2
# Zbtb7b     Zbtb7b          2
#
# $`3`
#        GuideName GuideGroup
# Acaca      Acaca          3
# Ambra1    Ambra1          3
# Amfr        Amfr          3
# Arih1      Arih1          3
# Cbll1      Cbll1          3
# Cfap57    Cfap57          3
# Cnot4      Cnot4          3
# Cyld        Cyld          3
# Dcaf7      Dcaf7          3
# Det1        Det1          3
# Dpf2        Dpf2          3
# Eed          Eed          3
# Efcab8    Efcab8          3
# Egr2        Egr2          3
# Fasn        Fasn          3
# Fbxw7      Fbxw7          3
# Foxo3      Foxo3          3
# Gsk3b      Gsk3b          3
# Hectd3    Hectd3          3
# Hira        Hira          3
# Icos        Icos          3
# Ifnar1    Ifnar1          3
# Ikbke      Ikbke          3
# Ints12    Ints12          3
# Junb        Junb          3
# Kat6a      Kat6a          3
# Kctd10    Kctd10          3
# Kctd13    Kctd13          3
# Kctd21    Kctd21          3
# Kctd5      Kctd5          3
# Klhl30    Klhl30          3
# Klhl6      Klhl6          3
# Lztr1      Lztr1          3
# March6    March6          3
# Msl2        Msl2          3
# Nf1          Nf1          3
# Nfkb1      Nfkb1          3
# Nsd1        Nsd1          3
# Patz1      Patz1          3
# Pias1      Pias1          3
# Prdm1      Prdm1          3
# Pten        Pten          3
# Rfwd2      Rfwd2          3
# Rnf139    Rnf139          3
# Socs3      Socs3          3
# Spag16    Spag16          3
# Strap      Strap          3
# Stub1      Stub1          3
# Syk          Syk          3
# Tab1        Tab1          3
# Tank        Tank          3
# Tbk1        Tbk1          3
# Tnf          Tnf          3
# Trim45    Trim45          3
# Trip12    Trip12          3
# Ube2j2    Ube2j2          3
# Wdfy2      Wdfy2          3
# Wdr61      Wdr61          3
# Wdr81      Wdr81          3
# Wdr91      Wdr91          3
# Zbtb25    Zbtb25          3
# Zfp106    Zfp106          3
# Zfp91      Zfp91          3
# Zmiz2      Zmiz2          3
#
# $`4`
#         GuideName GuideGroup
# Aamp         Aamp          4
# Bop1         Bop1          4
# Cirh1a     Cirh1a          4
# Dcaf13     Dcaf13          4
# Grb2         Grb2          4
# Myc           Myc          4
# Nle1         Nle1          4
# Nol10       Nol10          4
# Pak1ip1   Pak1ip1          4
# Ptpn11     Ptpn11          4
# Rack1       Rack1          4
# Raf1         Raf1          4
# Rrp9         Rrp9          4
# Taf5         Taf5          4
# Tbl3         Tbl3          4
# Uhrf1       Uhrf1          4
# Utp15       Utp15          4
# Utp18       Utp18          4
# Vprbp       Vprbp          4
# Wdr3         Wdr3          4
# Wdr36       Wdr36          4
# Wdr43       Wdr43          4
# Wdr5         Wdr5          4
# Wdr74       Wdr74          4
# Wdr75       Wdr75          4
#
# $`5`
#         GuideName GuideGroup
# Cdc40       Cdc40          5
# Ddx41       Ddx41          5
# Plrg1       Plrg1          5
# Ppil2       Ppil2          5
# Ppwd1       Ppwd1          5
# Prpf19     Prpf19          5
# Prpf4       Prpf4          5
# Sart1       Sart1          5
# Smu1         Smu1          5
# Snrnp40   Snrnp40          5
# Wdr70       Wdr70          5

# %%
ProteinComplexes=list()

for(i in 1:nrow(proComp)){
  ProteinComplexes <- lappend(ProteinComplexes, strsplit(as.character(proComp[i,"subunits.Gene.name."]) , ";")[[1]])
}
names(ProteinComplexes) <- proComp$ComplexName
ProteinComplexes <- ProteinComplexes[!duplicated(names(ProteinComplexes))]

# %%
length(ProteinComplexes)
# Out:
# [1] 647

# %%
testSignOfKOOnProComp <- function(KOEffectedGenes, ProCompGenes, Universe, KOGene, ProComplex, allTests){
    
    if(length(ProCompGenes[ProCompGenes %in% KOEffectedGenes]) > 1){
        myDF = data.frame(koGenes = c(length(KOEffectedGenes[KOEffectedGenes %in% ProCompGenes]), length(ProCompGenes[ProCompGenes %ni% KOEffectedGenes])),
              restNo = c( length(KOEffectedGenes[KOEffectedGenes %ni% ProCompGenes]), length(Universe[Universe %ni% unique(c(KOEffectedGenes, ProCompGenes))])))

        testRes_g <- fisher.test(x= myDF, alternative = "greater")
        return(c(KOGene, ProComplex, testRes_g$p.value))
    }else{
        return(c(KOGene, ProComplex, 1))
    }

}

# %%
length(unique(c(colnames(coefsAll), koGuideNames)))
# Out:
# [1] 7179

# %%
length(koGuideNames)
# Out:
# [1] 329

# %%
dim(coefsAll)
# Out:
# [1]  329 1041

# %%
allTests = list()
for(i in 1:length(guideModulesSplit)){
    for(j in 1:length(ProteinComplexes)){
        allTests <- lappend(allTests, testSignOfKOOnProComp(KOEffectedGenes=guideModulesSplit[[i]]$GuideName,
                                          ProCompGenes=ProteinComplexes[[j]],
                                          Universe=unique(koGuideNames),
                                          KOGene=names(guideModulesSplit)[i],
                                          ProComplex=names(ProteinComplexes)[j],
                                          allTests = allTests))
    }
}

# %%
allTests <- data.frame(do.call(rbind, allTests), stringsAsFactors = FALSE)

# %%
colnames(allTests) = c("KOGene", "ProComplex", "Pval")

# %%
allTests <- allTests[allTests$Pval < 0.1,]

# %%
length(unique(allTests$ProComplex))
# Out:
# [1] 12

# %%
dim(allTests)
# Out:
# [1] 12  3

# %%
allTests
# Out:
#      KOGene
# 429  0
# 430  0
# 671  1
# 1075 1
# 1210 1
# 1516 2
# 1517 2
# 1726 2
# 1826 2
# 2655 4
# 2824 4
# 2917 4
#      ProComplex
# 429  Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
# 430  Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)
# 671  Src1-Ep300-Crebbp complex
# 1075 Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
# 1210 Akt-Arrb2-Ppp2ca-Ppp2r2a complex
# 1516 Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)
# 1517 Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)
# 1726 Keap1-Nrf2-Cul3 complex
# 1826 Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1
# 2655 cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex
# 2824 Frs2-Grb2-Shp2 complex, FGF stimulated
# 2917 Grb2-Shp2 complex, FGF stimulated
#      Pval
# 429  0.0642789515568481
# 430  0.0409596346031124
# 671  0.0129699494740236
# 1075 0.0760355840731281
# 1210 0.0247604108284295
# 1516 0.0234618633728798
# 1517 0.0234618633728798
# 1726 0.0122507127593603
# 1826 0.0374522183132459
# 2655 0.00790741358589905
# 2824 0.00166016224172285
# 2917 0.000562822215718499

# %%
allTestsSplit <- split(allTests, f = allTests$ProComplex)

# %%
allTestsSplit
# Out:
# $`Akt-Arrb2-Ppp2ca-Ppp2r2a complex`
#      KOGene                       ProComplex               Pval
# 1210      1 Akt-Arrb2-Ppp2ca-Ppp2r2a complex 0.0247604108284295
#
# $`cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex`
#      KOGene                              ProComplex                Pval
# 2655      4 cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex 0.00790741358589905
#
# $`Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)`
#     KOGene
# 430      0
#                                                                                          ProComplex
# 430 Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)
#                   Pval
# 430 0.0409596346031124
#
# $`Frs2-Grb2-Shp2 complex, FGF stimulated`
#      KOGene                             ProComplex                Pval
# 2824      4 Frs2-Grb2-Shp2 complex, FGF stimulated 0.00166016224172285
#
# $`Grb2-Shp2 complex, FGF stimulated`
#      KOGene                        ProComplex                 Pval
# 2917      4 Grb2-Shp2 complex, FGF stimulated 0.000562822215718499
#
# $`Keap1-Nrf2-Cul3 complex`
#      KOGene              ProComplex               Pval
# 1726      2 Keap1-Nrf2-Cul3 complex 0.0122507127593603
#
# $`Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n)`
#     KOGene
# 429      0
#                                                                                                         ProComplex
# 429 Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
#                   Pval
# 429 0.0642789515568481
#
# $`Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)`
#      KOGene
# 1075      1
#                                                                                                    ProComplex
# 1075 Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
#                    Pval
# 1075 0.0760355840731281
#
# $`Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1`
#      KOGene                      ProComplex               Pval
# 1826      2 Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1 0.0374522183132459
#
# $`Src1-Ep300-Crebbp complex`
#     KOGene                ProComplex               Pval
# 671      1 Src1-Ep300-Crebbp complex 0.0129699494740236
#
# $`Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)`
#      KOGene                                     ProComplex               Pval
# 1517      2 Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1) 0.0234618633728798
#
# $`Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)`
#      KOGene                                      ProComplex               Pval
# 1516      2 Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1) 0.0234618633728798

# %%
myRes <- sapply(allTestsSplit, function(x){return(paste(unique(x[,"KOGene"]), collapse = ", "))})

# %%
myRes
# Out:
#                                                                               Akt-Arrb2-Ppp2ca-Ppp2r2a complex
#                                                                                                            "1"
#                                                                        cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex
#                                                                                                            "4"
#                Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)
#                                                                                                            "0"
#                                                                         Frs2-Grb2-Shp2 complex, FGF stimulated
#                                                                                                            "4"
#                                                                              Grb2-Shp2 complex, FGF stimulated
#                                                                                                            "4"
#                                                                                        Keap1-Nrf2-Cul3 complex
#                                                                                                            "2"
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
#                                                                                                            "0"
#       Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
#                                                                                                            "1"
#                                                                                Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1
#                                                                                                            "2"
#                                                                                      Src1-Ep300-Crebbp complex
#                                                                                                            "1"
#                                                                 Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)
#                                                                                                            "2"
#                                                                Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)
#                                                                                                            "2"

# %%
myRes
# Out:
#                                                                               Akt-Arrb2-Ppp2ca-Ppp2r2a complex
#                                                                                                            "1"
#                                                                        cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex
#                                                                                                            "4"
#                Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)
#                                                                                                            "0"
#                                                                         Frs2-Grb2-Shp2 complex, FGF stimulated
#                                                                                                            "4"
#                                                                              Grb2-Shp2 complex, FGF stimulated
#                                                                                                            "4"
#                                                                                        Keap1-Nrf2-Cul3 complex
#                                                                                                            "2"
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
#                                                                                                            "0"
#       Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
#                                                                                                            "1"
#                                                                                Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1
#                                                                                                            "2"
#                                                                                      Src1-Ep300-Crebbp complex
#                                                                                                            "1"
#                                                                 Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)
#                                                                                                            "2"
#                                                                Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)
#                                                                                                            "2"

# %%
head(allTests)
# Out:
#      KOGene
# 429  0
# 430  0
# 671  1
# 1075 1
# 1210 1
# 1516 2
#      ProComplex
# 429  Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
# 430  Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)
# 671  Src1-Ep300-Crebbp complex
# 1075 Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)
# 1210 Akt-Arrb2-Ppp2ca-Ppp2r2a complex
# 1516 Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)
#      Pval
# 429  0.0642789515568481
# 430  0.0409596346031124
# 671  0.0129699494740236
# 1075 0.0760355840731281
# 1210 0.0247604108284295
# 1516 0.0234618633728798

# %%
myResMat = data.frame(matrix(0, ncol = 6, nrow = length(unique(allTests$ProComplex))))

# %%
dim(myResMat)
# Out:
# [1] 12  6

# %%
colnames(myResMat) = c("0","1","2","3","4","5")
rownames(myResMat) = unique(allTests$ProComplex)

# %%
myResMat
# Out:
#                                                                                                                0
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                1
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                2
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                3
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                4
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                5
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0

# %%
allTests[i,"KOGene"]
# Out:
# [1] "2"

# %%
myResMat
# Out:
#                                                                                                                0
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                1
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                2
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                3
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                4
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                5
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0

# %%
for( i in 1:nrow(allTests)){
    myResMat[allTests[i,"ProComplex"], allTests[i,"KOGene"]] = 1
}

# %%
myResMat
# Out:
#                                                                                                                0
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 1
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                1
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                1
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      1
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       1
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               1
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                2
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                1
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 1
# Keap1-Nrf2-Cul3 complex                                                                                        1
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                1
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                3
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0
#                                                                                                                4
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        1
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         1
# Grb2-Shp2 complex, FGF stimulated                                                                              1
#                                                                                                                5
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
# Ubiquitin E3 ligase (Fbxo2, Skp1a, Cul1, Rbx1)                                                                 0
# Keap1-Nrf2-Cul3 complex                                                                                        0
# Rbx1- Cul1-Skp1-Fbxw8-Cul7-Rbx1                                                                                0
# cRET-Shc-Grb2-Gab2-P85PI3K-Shp2 complex                                                                        0
# Frs2-Grb2-Shp2 complex, FGF stimulated                                                                         0
# Grb2-Shp2 complex, FGF stimulated                                                                              0

# %%
head(myResMat)
# Out:
#                                                                                                                0
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 1
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                1
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
#                                                                                                                1
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      1
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       1
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               1
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
#                                                                                                                2
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                1
#                                                                                                                3
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
#                                                                                                                4
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0
#                                                                                                                5
# Membrane-associated multicomponent signaling complex, anti-CD40 stimulated (Cd40, Ikbkg, Map3k1, Traf2, Ube2n) 0
# Cytosolic multicomponent signaling complex, anti-CD40 stimulated, (Ikbkg, Map3k1, Traf2, Ube2n)                0
# Src1-Ep300-Crebbp complex                                                                                      0
# Multicomponent signaling complex, anti-CD40 stimulated,(Birc2, Birc3, Cd40, Ikbkg, Map3k1, Traf2, Ube2n)       0
# Akt-Arrb2-Ppp2ca-Ppp2r2a complex                                                                               0
# Ubiquitin E3 ligase (Fbxo32, Skp1a, Cul1, Rbx1)                                                                0

# %%
options(repr.plot.width=12, repr.plot.height=4)
pheatmap(myResMat, cluster_cols=FALSE,clustering_method="ward.D2", treeheight_col = 0, treeheight_row = 0, color = c("lightgrey", "red"))
# Out:
# plot without title

# %%
KOEffectedGenes[KOEffectedGenes %ni% ProCompGenes]
# Out:
# Error in eval(expr, envir, enclos): object 'KOEffectedGenes' not found
# Traceback:

# %%
length(ProCompGenes[ProCompGenes %ni% KOEffectedGenes])

# %%
unique(c(KOEffectedGenes, ProCompGenes))

# %%
length(universe[universe %ni% unique(c(KOEffectedGenes, ProCompGenes))])
