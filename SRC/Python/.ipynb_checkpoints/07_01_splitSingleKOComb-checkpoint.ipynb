# %%
from libraries import *
from parameters import *

# %%
os.getcwd()
os.chdir(projectDir)

# %%
# %%time

adata = sc.read("outputs/anndata/adata-hash-features_singlets_05242020.h5ad")
fBarMat = adata.obs[adata.uns['feature_barcode_names']]
# Out:
# /home/eraslab1/miniconda3/lib/python3.8/site-packages/anndata/compat/__init__.py:232: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /home/eraslab1/miniconda3/lib/python3.8/site-packages/anndata/compat/__init__.py:232: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# CPU times: user 16.6 s, sys: 44.3 s, total: 1min
# Wall time: 1min

# %%
fBarMat.shape
# Out:
# (519535, 3720)

# %%
fBarMat[fBarMat>0] = 1
# Out:
# /tmp/ipykernel_89491/394327979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fBarMat[fBarMat>0] = 1
# /tmp/ipykernel_89491/394327979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fBarMat[fBarMat>0] = 1

# %%
adata.obs = adata.obs.assign(KONo = fBarMat.sum(axis=1).to_numpy()) 
adata.obs = adata.obs.assign(KOType = "SingleKO")
adata.obs.loc[adata.obs.KONo > 1,'KOType'] = "MultipleKO"

# %%
adata.obs["KOType"].value_counts()
# Out:
# SingleKO      341664
# MultipleKO    177871
# Name: KOType, dtype: int64

# %%
for elem in fBarMat.columns.to_list():
     adata.obs.loc[adata.obs[elem] > 0,elem] = 1

# %%
adataSingle = adata[adata.obs.KOType == "SingleKO", :]
adataMultiple = adata[adata.obs.KOType == "MultipleKO", :]

# %%
f, ax = plt.subplots(figsize=(8, 8))
sc.pl.umap(adataSingle, color='leiden', legend_loc='on data', legend_fontoutline=3, 
           legend_fontsize=14, legend_fontweight='normal', title='Clusters', ax=ax, show=False, size=1);
# Out:
# /home/eraslab1/miniconda3/lib/python3.8/site-packages/anndata/_core/anndata.py:1235: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   df[key] = c

# %%
adataSingle.shape
# Out:
# (341664, 13811)

# %%
adataMultiple.shape
# Out:
# (177871, 13811)

# %%
sc.pl.umap(adata, color=['sample_name', 'hash_assignment'], size=1, cmap='Reds', wspace=0.8);

# %%
adataSingle.write('outputs/anndata/adata-hash-features_singlets_SingleKO_05242020.h5ad')

# %%
#adataMultiple.write('outputs/anndata/adata-hash-features_singlets_MultipleKO_05242020.h5ad')
